# %% [markdown]
# # Clustering
# Below shows examples of clustering using hierarchical,CURE and DBSCAN clustering methods in kdb+/q.
#
# ### Dependencies
# To run the below notebook, the following dependencies are required.
# ```
# - embedPy
# - matplotlib
# - pyclustering
# - scikit learn
# ```

# %% [markdown]
# ### Example 1

# %%
\l ml/ml.q
.ml.loadfile`:clust/init.q
\l graphics.q
plt:.p.import`matplotlib.pyplot
.p.import[`mpl_toolkits.mplot3d]`:Axes3D;
fcps:.p.import[`pyclustering.samples.definitions]`:FCPS_SAMPLES
read:.p.import[`pyclustering.utils]`:read_sample

# %%
d1:(60#"F";",")0:`:data/ss5.csv
plt[`:scatter][;]. flip d1;
plt[`:show][];

# %%
/plot[`cure;d1;-1_(cross/)(4;-1_key .ml.clust.kd.i.dd;5;0;01b;0b)] --add C and streaming
plot[`cure;d1;(cross/)(4;-1_key .ml.clust.kd.i.dd;5;0)]

# %%
plot[`dbscan;d1;(cross/)(-1_key .ml.clust.kd.i.dd;5;5)]

# %%
plot[`hc;d1;(cross/)(4;-1_key .ml.clust.kd.i.dd;-1_key .ml.clust.kd.i.ld)]

# %%
plot[`ward;d1;(4;`e2dist;`ward)]

# %%
plot[`kmeans;d1;(cross/)(4;1000;1b;key .ml.clust.kd.i.dd)]

# %% [markdown]
# ### Example 2

# %%
d2:flip@[;`Income`SpendingScore]("SSFFF";(),",")0:`:data/cust.csv
plt[`:scatter][;]. flip d2;
plt[`:show][];

# %%
/plot[`cure;d2;-1_(cross/)(4;-1_key .ml.clust.kd.i.dd;5;0;01b;0b)]
plot[`cure;d2;(cross/)(4;-1_key .ml.clust.kd.i.dd;5;0)]

# %%
plot[`dbscan;d2;(cross/)(-1_key .ml.clust.kd.i.dd;3;100)]

# %%
plot[`hc;d2;(cross/)(5;-1_key .ml.clust.kd.i.dd;-1_key .ml.clust.kd.i.ld)]

# %%
plot[`ward;d2;(5;`e2dist;`ward)]

# %%
plot[`kmeans;d2;(cross/)(5;20;1b;key .ml.clust.kd.i.dd)]

# %% [markdown]
# ### Example 3

# %%
dsc:{[n;r;s](r+n?s-r)*/:(cos;sin)@\:4*n?acos 0}
d3 :flip(-5 1)+(1 1.5)*dsc[1000;0;1.8],'dsc[2000;3.1;4.2],'dsc[4000;5.2;6.5]
d3,:flip(4 -1)+(1 8)*dsc[4000;0;1.]
d3@:neg[1000&count d3]?count d3
plt[`:scatter][;]. flip d3;
plt[`:show][];

# %%
/plot[`cure;d3;-1_(cross/)(4;-1_key .ml.clust.kd.i.dd;30;0;01b;0b)]
plot[`cure;d3;(cross/)(4;-1_key .ml.clust.kd.i.dd;30;0)]

# %%
plot[`dbscan;d3;(cross/)(-1_key .ml.clust.kd.i.dd;2;1.2)]

# %%
plot[`hc;d3;(cross/)(4;-1_key .ml.clust.kd.i.dd;-1_key .ml.clust.kd.i.ld)]

# %%
plot[`ward;d3;(4;`e2dist;`ward)]

# %%
plot[`kmeans;d2;(cross/)(5;20;1b;key .ml.clust.kd.i.dd)]

# %% [markdown]
# ### Example 4 - 3D

# %%
d4:read[fcps`:SAMPLE_CHAINLINK]`
fig:plt[`:figure][];
ax:fig[`:add_subplot][111;`projection pykw"3d"];
ax[`:scatter][;;]. flip d4;
plt[`:show][];

# %%
/plot[`cure;d4;-1_(cross/)(2;-1_key .ml.clust.kd.i.dd;30;0;01b;0b)]
plot[`cure;d4;(cross/)(2;-1_key .ml.clust.kd.i.dd;30;0)]

# %%
plot[`dbscan;d4;(cross/)(-1_key .ml.clust.kd.i.dd;100;.6)]

# %%
plot[`hc;d4;(cross/)(2;-1_key .ml.clust.kd.i.dd;-1_key .ml.clust.kd.i.ld)]

# %%
plot[`ward;d4;(2;`e2dist;`ward)]

# %%
/k-means with e2dist, edist, mdist and cshev
plot[`kmeans;d4;(cross/)(2;100;1b;key .ml.clust.kd.i.dd)]

# %% [markdown]
# ---
